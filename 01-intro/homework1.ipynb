# %%
pip install pyarrow
# Out:
# ...
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#    --- ------------------------------------ 2.1/25.1 MB 10.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 3.1/25.1 MB 9.2 MB/s eta 0:00:03
#    ------ --------------------------------- 3.9/25.1 MB 6.3 MB/s eta 0:00:04
#    ------- -------------------------------- 5.0/25.1 MB 6.0 MB/s eta 0:00:04
#    --------- ------------------------------ 6.0/25.1 MB 5.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 7.1/25.1 MB 5.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 7.3/25.1 MB 5.6 MB/s eta 0:00:04
#    ------------ --------------------------- 7.6/25.1 MB 5.0 MB/s eta 0:00:04
#    -------------- ------------------------- 8.9/25.1 MB 4.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 10.7/25.1 MB 5.2 MB/s eta 0:00:03
#    ------------------ --------------------- 11.5/25.1 MB 5.3 MB/s eta 0:00:03
# ...

# %%
import pandas as pd

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
# 1. tpep_dropoff_datetime/tpep_pickup_datetime are given as string in df so we need to convert them to datetime
# 2. convert duration to minutes

df.tpep_dropoff_datetime = pd.to_datetime(df['tpep_dropoff_datetime'])
df.tpep_pickup_datetime = pd.to_datetime(df['tpep_pickup_datetime'])

df['duration'] = df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime'] 
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.duration = df.duration.apply(lambda td: td.total_seconds()/60)
df[80:90]
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 80         2  2024-01-01 00:21:22   2024-01-01 00:45:26              1.0
# 81         2  2024-01-01 00:52:30   2024-01-01 01:10:29              1.0
# 82         2  2024-01-01 00:08:48   2024-01-01 00:09:33              1.0
# 83         2  2024-01-01 00:33:59   2024-01-01 00:39:53              1.0
# 84         1  2024-01-01 00:27:13   2024-01-01 00:29:51              2.0
# 85         1  2024-01-01 00:50:29   2024-01-01 01:42:04              4.0
# 86         1  2024-01-01 00:54:24   2024-01-01 01:28:53              1.0
# 87         2  2024-01-01 00:27:02   2024-01-01 01:03:56              1.0
# 88         2  2024-01-01 00:21:00   2024-01-01 00:46:17              1.0
# 89         2  2024-01-01 00:50:40   2024-01-01 01:13:44              1.0
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 80           1.88         1.0                  N           234           162
# ...

# %%
# !pip uninstall matplotlib seaborn
# Out:
# ^C

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\envs\gpu_env\lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_27292\2870131861.py", line 1, in <module>
#     import seaborn as sns
#   File "C:\Users\admin\anaconda3\envs\gpu_env\lib\site-packages\seaborn\__init__.py", line 9, in <module>
#     from .matrix import *  # noqa: F401,F403
#   File "C:\Users\admin\anaconda3\envs\gpu_env\lib\site-packages\seaborn\matrix.py", line 16, in <module>
#     from . import cm
#   File "C:\Users\admin\anaconda3\envs\gpu_env\lib\site-packages\seaborn\cm.py", line 2, in <module>
#     from seaborn._compat import register_colormap
#   File "C:\Users\admin\anaconda3\envs\gpu_env\lib\site-packages\seaborn\_compat.py", line 8, in <module>
# ...

# %%
g = sns.displot(df['duration'])
g.set_axis_labels("Duration", "Count")
g.set(xlim=(-5, 125))  # Replace with the range you're interested in
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 g = sns.displot(df['duration'])
#       2 g.set_axis_labels("Duration", "Count")
#       3 g.set(xlim=(-5, 125))
#
# NameError: name 'sns' is not defined

# %%
df['duration'].describe()

# %%
((df.duration >= 1) & (df.duration <= 60)).mean()

# %%
df['duration'].describe()
