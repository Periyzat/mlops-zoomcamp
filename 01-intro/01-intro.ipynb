# %%
# %cd /workspaces/mlops-zoomcamp/01-intro/data
# Out:
# [WinError 3] The system cannot find the path specified: '/workspaces/mlops-zoomcamp/01-intro/data'
# C:\Users\admin\OneDrive\Desktop\PeriyDL\MLOps\mlops-zoomcamp\01-intro

# %%
# !wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-01.parquet
# Out:
#   Cell In[5], line 1
#     wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-01.parquet
#          ^
# SyntaxError: invalid syntax

# %%
# %cd /workspaces/mlops-zoomcamp/01-intro/data
# Out:
# /workspaces/mlops-zoomcamp/01-intro/data

# %%
# !wget https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-02.parquet
# Out:
# --2024-09-07 06:27:50--  https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-02.parquet
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 3.164.82.40, 3.164.82.197, 3.164.82.160, ...
# Connecting to d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|3.164.82.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1283805 (1.2M) [binary/octet-stream]
# Saving to: ‘green_tripdata_2024-02.parquet.1’
#
# green_tripdata_2024 100%[===================>]   1.22M  1.64MB/s    in 0.7s
#
# 2024-09-07 06:27:51 (1.64 MB/s) - ‘green_tripdata_2024-02.parquet.1’ saved [1283805/1283805]

# %%
# !ls /workspaces/mlops-zoomcamp/01-intro/data
# Out:
# green_tripdata_2024-01.parquet	green_tripdata_2024-02.parquet.1
# green_tripdata_2024-02.parquet

# %%
import pandas as pd

# %%
df = pd.read_parquet('/workspaces/mlops-zoomcamp/01-intro/data/green_tripdata_2024-01.parquet')

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2024-01-01 00:46:55   2024-01-01 00:58:25                  N
# 1             2  2024-01-01 00:31:42   2024-01-01 00:52:34                  N
# 2             2  2024-01-01 00:30:21   2024-01-01 00:49:23                  N
# 3             1  2024-01-01 00:30:20   2024-01-01 00:42:12                  N
# 4             2  2024-01-01 00:32:38   2024-01-01 00:43:37                  N
# ...         ...                  ...                   ...                ...
# 56546         2  2024-01-31 20:46:00   2024-01-31 20:55:00               None
# 56547         2  2024-01-31 21:06:00   2024-01-31 21:11:00               None
# 56548         2  2024-01-31 21:36:00   2024-01-31 21:40:00               None
# 56549         2  2024-01-31 22:45:00   2024-01-31 22:51:00               None
# 56550         2  2024-01-31 22:28:00   2024-01-31 22:59:00               None
#
# ...

# %%
print("aaa")
# Out:
# aaa
